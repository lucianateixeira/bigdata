# %%
from IPython.display import Image
image_path = 'java-hadoop.png'
Image(filename=image_path)

# %%
from IPython.display import Image
image_path = 'check-file.png'
Image(filename=image_path)

# %%
from IPython.display import Image
image_path = 'dataset-to-hadoop.png'
Image(filename=image_path)

# %%
from IPython.display import Image
image_path = 'pyspark.png'
Image(filename=image_path)

# %%
from IPython.display import Image
image_path = 'python-notebook.png'
Image(filename=image_path)

# %%
from IPython.display import Image
image_path = 'python-script.png'
Image(filename=image_path)

# %%
from IPython.display import Image
image_path = 'scala-1.png'
Image(filename=image_path)

# %%
from IPython.display import Image
image_path = 'scala-2.png'
Image(filename=image_path)

# %%
from IPython.display import Image
image_path = 'scala-3.png'
Image(filename=image_path)

# %%
from IPython.display import Image
image_path = 'scala-4.png'
Image(filename=image_path)

# %%
from IPython.display import Image
image_path = 'scala-5.png'
Image(filename=image_path)

# %%
from IPython.display import Image
image_path = 'scala-6.png'
Image(filename=image_path)

# %%
from IPython.display import Image
image_path = 'spark-scala.png'
Image(filename=image_path)

# %%
from IPython.display import Image
image_path = 'spark-version.png'
Image(filename=image_path)

# %%
from IPython.display import Image
image_path = 'spark-version.png'
Image(filename=image_path)
